# %%
<meta charset="utf-8">



<script>
	alert("La edad de Cristian es ...")

	alert("?")
    
</script>



<script>
	document.write("El promedio de edad de Juan, Pedro y Carlos es...")
	document.write("<br>")//separa
	document.write((20+25+15)/3)

	document.write("La suma de las edades de Juan, Pedro y Carlos es...<br>" +(20+25+15));

   </script>

---------------------------------------------************************************--------------------------

<meta charset="utf-8">

<h1>Programa</h1>


<script>

	var anho = 2025;

	document.write("Juan tiene  " + (anho-2000) + " anos");
	document.write("<br>");//separa
	document.write("Pedro tiene  " + (anho-1995) + " anos");


	var anho = 2030;
	document.write("<br>");//separa
	document.write("Pedro tiene  " + (anho-2005) + " anos");

	var anho = 2030;
	document.write("<br>");
	document.write("<br>");
	document.write("<br>");
	document.write("<br>");


	var anho = 2020;

document.write("Jiemena tiene  " + (anho-2010) + " anos");
	document.write("<br>");//separa
	document.write("<br>");
	document.write("<br>");

	document.write("Paola tiene  " + (anho-1995) + " anos");
	document.write("<br>");//separa
	document.write("<br>");
	document.write("<br>");

	document.write("Laura tiene  " + (anho-2005) + " anos");
	document.write("<br>");//separa
	document.write("<br>");
	document.write("<br>");

	var  edadJimena = 25;
	var  edadPaola = 10;
	var  edadLaura = 15;

	var nombre1 = "Jimena";
	var nombre2 = "Paola";
	var nombre3 = "Laura";



	promedio = (edadJimena+edadPaola+edadLaura) /3

	document.write("<br>");
	document.write("<br>");
	document.write("El promedio de las edades de:  " +  nombre1 + ", " + nombre2 + " y " + nombre3 + " es: " + Math.round(promedio));
	</script>

	-----------------------****************************************************-----------------------------------------
		<meta charset="UTF-8">



<script>


var mult = 8;

    document.write("5 por 1 es " + mult * 1 + "<br>");
    document.write("5 por 2 es " + mult * 2 + "<br>");
    document.write("5 por 3 es " + mult * 3 + "<br>");
    document.write("5 por 4 es " + mult * 4 + "<br>");
    document.write("5 por 5 es " + mult * 5 + "<br>");
    document.write("5 por 6 es " + mult * 6 + "<br>");
    document.write("5 por 7 es " + mult * 7 + "<br>");
    document.write("5 por 8 es " + mult * 8 + "<br>");
    document.write("5 por 9 es " + mult * 9 + "<br>");
    document.write("5 por 10 es " + mult * 10 + "<br>");
</script>

-------------------------------------------------------------------------------------------------------------------------------------

<meta charset="UTF-8">

<h3>¿Alcohol o gasolina?</h3>

<script>

alert("Si un carro tiene un tanque de 40 litros.");
alert("Usando gasolina y consumiendo todo el tanque se hace un recorrido de 480 kilómetros");


	document.write("<br>");//
	document.write("<br>");//
	document.write("<br>");//
	document.write("<br>");//
	document.write("¿Cuál es la eficiencia del carro usando gasolina?" +(480/40));


</script>
-------------------------------------------------------------------------------------------------------------------------------------------

<meta charset="UTF-8">

<h3>¿Alcohol o gasolina?</h3>

<script>

alert("si el carro usa alcohol como combustible, el mismo tanque de 40 litros hace un recorrido de 300 kilómetros");



	document.write("<br>");//
	document.write("<br>");//
	document.write("<br>");//
	document.write("<br>");//
	document.write("¿Cuál es el la eficiencia del carro usando alcohol?<br>" +(300/40));


</script>
------------------------------------------------------------------------------------------------------------------------

<meta charset="UTF-8">
<h3>¿Alcohol o Gasolina?</h3>

<script> 
var tanque = 40;

var caminoConGasolina = 480;
var consumoDeGasolina = caminoConGasolina/tanque;

var caminoConAlcohol = 300;
var consumoDeAlcohol = caminoConAlcohol/tanque;

document.write("La eficiencia del carro usando gasolina es " + consumoDeGasolina + " km/L"); 
document.write("<br>"); 
document.write("La eficiencia del carro usando alcohol es " + consumoDeAlcohol + " km/L");

</script>
----------------------------------------------------------------------------------------------------------------------------------
<meta charset="utf-8">

<h1>Programa</h1>


<script>

	var saltolinea = "<br><br>"//satodelinea
	var anho = 2025;

	document.write("Juan tiene  " + (anho-2000) + " anos");
	document.write(saltolinea);//separa
	document.write("Pedro tiene  " + (anho-1995) + " anos");


	var anho = 2030;
	document.write(saltolinea);//separa
	document.write("Pedro tiene  " + (anho-2005) + " anos");

	var anho = 2030;
	document.write(saltolinea);
	

	var anho = 2020;

document.write("Jiemena tiene  " + (anho-2010) + " anos");
	document.write(saltolinea);//separa
	

	document.write("Paola tiene  " + (anho-1995) + " anos");
	document.write(saltolinea);//separa
	

	document.write("Laura tiene  " + (anho-2005) + " anos");
	document.write(saltolinea);

	var  edadJimena = 25;
	var  edadPaola = 10;
	var  edadLaura = 15;

	var nombre1 = "Jimena";
	var nombre2 = "Paola";
	var nombre3 = "Laura";



	promedio = (edadJimena+edadPaola+edadLaura) /3

	document.write(saltolinea);
	document.write("El promedio de las edades de:  " +  nombre1 + ", " + nombre2 + " y " + nombre3 + " es: " + Math.round(promedio));
	</script>

<meta charset="utf-8">

<h1>Programa</h1>


<script>

	function saltarlinea() {
		document.write("<br><br><br>");
	}	


	
	var anho = 2025;

	document.write("Juan tiene  " + (anho-2000) + " anos");
	saltarlinea();

	document.write("Pedro tiene  " + (anho-1995) + " anos");


	var anho = 2030;
	saltarlinea();
	document.write("Pedro tiene  " + (anho-2005) + " anos");
	</script>
	
	<meta charset="utf-8">

<h1>Programa</h1>


<script>

	function saltarlinea() {
		document.write("<br><br><br>");
	}	

	function imprimir(frase) {
		document.write(frase)

	}	


	
	var anho = 2025;

	imprimir("hola amigos");
	saltarlinea();

	//este codigo calcula las edades de Juan Pedro y Carlos

	imprimir("Juan tiene  " + (anho-2000) + " anos");
	saltarlinea();

	imprimir("Pedro tiene  " + (anho-1995) + " anos");


	var anho = 2030;
	saltarlinea();
	imprimir("Pedro tiene  " + (anho-2005) + " anos");

	</script>


<meta charset="utf-8">

<h1>Programa</h1>


<script>

	function saltarlinea() {
		document.write("<br><br>");
	}	

	function imprimir(frase) {
		document.write(frase)
		saltarlinea();

	}	


	
	var anho = 2025;

	imprimir("hola amigos");

	//este codigo calcula las edades de Juan Pedro y Carlos

	imprimir("Juan tiene  " + (anho-2000) + " anos");

	imprimir("Pedro tiene  " + (anho-1995) + " anos");


	var anho = 2030;
	imprimir("Pedro tiene  " + (anho-2005) + " anos");

	</script>

	<meta charset="UTF-8">
<script>
    function saltarLinea() {
        document.write("<br>");
    }

    function imprimir(frase) {
        document.write(frase);
    }

    var miEdad = 18;//Escribe un programa que muestre el mensaje ¨Nuestra diferencia de edad es
    var edadHermano = 15;

    imprimir("Nuestra diferencia de edad es " + (miEdad - edadHermano));
 </script>

 <meta charset="utf-8">

<h1>Programa Calculo de IMC</h1>


<script>

    function saltarlinea() {
        document.write("<br><br>");
    }   

    function imprimir(frase) {
        document.write(frase)
        saltarlinea();

    }   

    pesoLingo = 75
    alturaLingo = 1.83
    imcLingo = pesoLingo / (alturaLingo * alturaLingo)

    imprimir(" El IMC de Lingo es: " + imcLingo);

    pesoFelipe = 71
    alturaFelipe = 1.72
    imcFelipe = pesoFelipe / (alturaFelipe * alturaFelipe)

    imprimir(" El IMC de Felipe es: " + imcFelipe);



  

    </script>

    <meta charset="utf-8">

<h1>Programa Calculo de IMC</h1>


<script>

    function saltarlinea() {
        document.write("<br><br>");
    }   

    function imprimir(frase) {
        document.write(frase)
        saltarlinea();

    }

    function calcularImc(peso,altura) {

        imc = peso / (altura * altura);
        return(imc);
    }    

    pesoLingo = 75
    alturaLingo = 1.83
    //imcLingo = pesoLingo / (alturaLingo * alturaLingo)
    imcLingo = calcularImc(pesoLingo,alturaLingo)
    imprimir(" El IMC de Lingo es: " + imcLingo);

    

    pesoFelipe = 71
    alturaFelipe = 1.72
    imcFelipe = pesoFelipe / (alturaFelipe * alturaFelipe)

    imprimir(" El IMC de Felipe es: " + imcFelipe);



  

    </script>

    <meta charset="utf-8">

<h1>Programa Calculo de IMC</h1>


<script>

    function saltarlinea() {
        document.write("<br><br>");
    }   

    function imprimir(frase) {
        document.write(frase)
        saltarlinea();

    }

    function calcularImc(peso,altura) {

        imc = peso / (altura * altura);
        return(imc);
    }    

    pesoLingo = 75
    alturaLingo = 1.83
    //imcLingo = pesoLingo / (alturaLingo * alturaLingo)
    imcLingo = calcularImc(pesoLingo,alturaLingo)
    imprimir(" El IMC de Lingo es: " + imcLingo);

    

    pesoFelipe = 71
    alturaFelipe = 1.90
    imcFelipe = calcularImc ( pesoFelipe, alturaFelipe)
    imprimir(" El IMC de Felipe es: " + imcFelipe);
    
    </script>

------------------------------------------------------------------------------------------------------------------------------------------
    <meta charset="utf-8">

<h1>Programa Calculo de IMC</h1>


<script>

    function saltarlinea() {
        document.write("<br><br>");
    }   

    function imprimir(frase) {
        document.write(frase)
        saltarlinea();

    }

    function calcularImc(peso,altura) {

        imc = peso / (altura * altura);
        imprimir("El imc calculado es " + imc);

    
    }    

   
    calcularImc(75,1.83);
    calcularImc(75,1.73);
    
    </script>

    --------------------------------------------------------------------

    <meta charset="utf-8">

<h1>Programa Calculo de IMC</h1>


<script>

    function saltarlinea() {
        document.write("<br><br>");
    }   

    function imprimir(frase) {
        document.write(frase)
        saltarlinea();

    }

    function calcularImc(peso,altura, nombre) {

        imc = peso / (altura * altura);
        imprimir("El imc calculado de  "  + nombre + " es " + imc);

    
    }    

   
    calcularImc(75,1.83, "Anders");
    calcularImc(75,1.73, "Antonua");
    
    </script>

    -********************************************************************************************
     <meta charset="utf-8">

<h1>Programa Calculo de IMC</h1>


<script>

    function saltarlinea() {
        document.write("<br><br>");
    }   

    function imprimir(frase) {
        document.write(frase)
        saltarlinea();

    }

    function calcularImc(peso,altura) {

        imc = peso / (altura * altura);
        return imc
    
    }    

    var imcLingo = calcularImc(71,1.72)
    var imcFelipe =calcularImc(75,1.73)

    imprimir("El promedio del imc calculado de Lingo y Felipe es:  " + (imcLingo+imcFelipe)/2);

   



    </script>
    ************************************************************************************************************
     <meta charset="utf-8">

<h1>Programa Calculo de IMC</h1>


<script>

    function saltarlinea() {
        document.write("<br><br>");
    }   

    function imprimir(frase) {
        document.write(frase)
        saltarlinea();

    }

    function calcularImc(peso,altura) {

       
        return (peso / (altura * altura));
    
    }    


    imprimir("El promedio del imc calculado de Lingo y Felipe es:  " + (calcularImc(71,1.72)+calcularImc(75,1.73))/2);
    imprimir("El promedio del imc calculado de Gabriela y Luisa es:  " + (calcularImc(65,1.68)+calcularImc(55,1.60))/2);

   
</script>
*****************************************************************************************************************************

<meta charset="UTF-8">


<h1>Programa Calculo de IMC</h1>


<script>

    function saltarlinea() {
        document.write("<br><br>");
    }   

    function imprimir(frase) {
        document.write(frase)
        saltarlinea();

    }

    function calcularImc(peso,altura) {

       
        return (peso / (altura * altura));
    
    }  

    PesoInformado =  prompt("informe su peso")
    alturaInformado = prompt("informe su altura")
    imcCalculado = calcularImc(PesoInformado, alturaInformado)


    imprimir("El promedio del imc calculado es:  " + imcCalculado);
    
   
</script>
-------------------------------------------------------------------------------------
<meta charset="UTF-8">


<h1>Programa Calculo de IMC</h1>


<script>

    function saltarlinea() {
        document.write("<br><br>");
    }   

    function imprimir(frase) {
        document.write(frase)
        saltarlinea();

    }

    function calcularImc(peso,altura) {

       
        return (peso / (altura * altura));
    
    }  

    nombre = prompt("informe su nombre")
    PesoInformado =  prompt(nombre + " informe su peso")
    alturaInformado = prompt(nombre + " informe su altura")
    imcCalculado = calcularImc(PesoInformado, alturaInformado)


    imprimir(nombre + " su imc calculado es:  " + imcCalculado);
    
   
</script>
