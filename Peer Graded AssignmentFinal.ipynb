# %% [markdown]
# #                My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ronaldo Enrique Cobos Ortiz
#      AI Engineer**

# %% [markdown]
# _I am interested in data science because I want to gain knowledge and money_

# %% [markdown]
# ###  This code will show you a little sum to have fun!

# %%
x1 = 1.1
y2 = 1.1

sum = x1 + y2

print (sum)
# Out:
# 2.2

# %% [markdown]
#  **_“Learn as if you will live forever, live like you will die tomorrow.”**_ — Mahatma Gandhi
#
#
#  www.coursera.com
#  ![Image of coursera](data:image/jpeg;base64,...)
